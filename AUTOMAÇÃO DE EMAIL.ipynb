# %%
import pyautogui as pa
import time
import pyperclip as pc


#CÓDIGO PARA AUTOMAÇÃO DE EMAIL
#ENTRADA E DOWLOAD DE ARQUIVOS!
pa.hotkey('ctrl','t')
drive ='https://drive.google.com/drive/my-drive'
pc.copy(drive)
pa.hotkey('ctrl', 'v')
pa.press('enter')
time.sleep(8)
pa.click(627, 565, clicks=2)
time.sleep(2)
pa.click(385, 369)
time.sleep(0.5)
pa.click(1161, 191)
time.sleep(0.5)
pa.click(1005, 590)

# %%
import pandas as pd
leitor=pd.read_excel(r'C:\Users\Lucas Guilherme\Downloads\excel.xlsx', engine='openpyxl')
display(leitor)
docs= leitor['Unnamed: 3'].sum()
# Out:
#           CONTAS A PAGAR    Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0                   Data     Histórico         1.0         1.0
# 1    2015-02-18 00:00:00  Fornecedor A       101.0      1500.0
# 2    2015-02-21 00:00:00  Fornecedor B       102.0      1250.0
# 3    2015-02-22 00:00:00  Fornecedor C       103.0       450.0
# 4    2015-02-23 00:00:00  Fornecedor A       104.0       580.0
# ..                   ...           ...         ...         ...
# 994                  NaN           NaN         NaN         NaN
# 995                  NaN           NaN         NaN         NaN
# 996                  NaN           NaN         NaN         NaN
# 997                  NaN           NaN         NaN         NaN
# 998                  NaN           NaN         NaN         NaN
#
#               Unnamed: 4 DATA ATUAL: 2021-05-03 00:00:00  Unnamed: 7  \
# 0                  Vcto.      Pagto.               Saldo         NaN
# ...

# %%
time.sleep(5)
pa.position()
# Out:
# Point(x=833, y=702)

# %%
import pyautogui as pa
import time
import pyperclip as pc

pa.hotkey('ctrl','t')
mail ='https://mail.google.com/mail/u/0/?tab=rm&ogbl#inbox'
pc.copy(mail)
pa.hotkey('ctrl', 'v')
time.sleep(3)
pa.press('enter')
time.sleep(5)
pa.click(109, 203)
time.sleep(2)
email = 'cymarnunes@hotmail.com'
pc.copy(email)
pa.hotkey('ctrl', 'v')
pa.press('tab')
pa.press('tab')
pa.write('Relatório das dívidas')
pa.press('tab')
pc.copy(f'''
Relatório de dívidas referentes aos trabalho do mês foi de R$ {docs:,.2f}
''')
pa.hotkey('ctrl', 'v')
time.sleep(0.5)
pa.click(833, 702)
